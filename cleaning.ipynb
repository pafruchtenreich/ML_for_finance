# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading and cleaning data

# %%
fed_rates = pd.read_csv("fed_rates.csv")
gold_prices = pd.read_csv("gold_historical_data.csv")

# %% [markdown]
# ## Gold prices

# %%
gold_prices = gold_prices.drop([0,1]).rename(columns={"Price":"Date"})

# %%
gold_prices["Date"] = pd.to_datetime(gold_prices["Date"])
gold_prices["Year"] = gold_prices["Date"].dt.year
gold_prices["Month"] = gold_prices["Date"].dt.month
gold_prices["Day"] = gold_prices["Date"].dt.day

# %%
gold_prices.drop(columns=["Date"], inplace=True)

# %%
cols = gold_prices.columns.to_list()
new_cols = cols[-3:] + cols[:-3]
gold_prices = gold_prices[new_cols]

# %%
gold_prices
# Out:
#       Year  Month  Day           Adj Close               Close  \
# 2     2000      8   30   273.8999938964844   273.8999938964844
# 3     2000      8   31  278.29998779296875  278.29998779296875
# 4     2000      9    1               277.0               277.0
# 5     2000      9    5  275.79998779296875  275.79998779296875
# 6     2000      9    6  274.20001220703125  274.20001220703125
# ...    ...    ...  ...                 ...                 ...
# 6062  2024     10   25    2740.89990234375    2740.89990234375
# 6063  2024     10   28    2742.89990234375    2742.89990234375
# 6064  2024     10   29    2768.39990234375    2768.39990234375
# 6065  2024     10   30              2788.5              2788.5
# 6066  2024     10   31   2738.300048828125   2738.300048828125
#
#                     High                 Low                Open Volume
# 2      273.8999938964844   273.8999938964844   273.8999938964844      0
# ...

# %% [markdown]
# ## Fed rates

# %%
fed_rates ## Issue : dataset ends in 2017 -> check https://fred.stlouisfed.org/categories/22 to download latest data
# Out:
#      Year  Month  Day  Federal Funds Target Rate  Federal Funds Upper Target  \
# 0    1954      7    1                        NaN                         NaN
# 1    1954      8    1                        NaN                         NaN
# 2    1954      9    1                        NaN                         NaN
# 3    1954     10    1                        NaN                         NaN
# 4    1954     11    1                        NaN                         NaN
# ..    ...    ...  ...                        ...                         ...
# 899  2016     12   14                        NaN                        0.75
# 900  2017      1    1                        NaN                        0.75
# 901  2017      2    1                        NaN                        0.75
# 902  2017      3    1                        NaN                        0.75
# 903  2017      3   16                        NaN                        1.00
#
# ...
